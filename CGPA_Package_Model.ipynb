# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshigangwani/CGPA_Package_Model/blob/main/CGPA_Package_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('placement.csv')

# %%
dataset.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(dataset['cgpa'],dataset['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(X_test)
# Out:
# [[8.58]
#  [7.15]
#  [5.88]
#  [6.22]
#  [4.57]
#  [4.79]
#  [5.32]
#  [6.86]
#  [8.35]
#  [6.87]
#  [8.94]
#  [7.9 ]
#  [6.93]
#  [5.91]
#  [7.32]
#  [7.82]
#  [5.09]
#  [7.42]
#  [6.94]
#  [7.73]
#  [6.19]
#  [7.28]
#  [6.73]
#  [7.2 ]
#  [8.21]
#  [6.75]
#  [7.87]
#  [7.6 ]
#  [8.63]
#  [5.12]
#  [8.15]
#  [7.36]
#  [8.31]
#  [6.6 ]
#  [6.59]
#  [7.47]
#  [7.93]
#  [6.29]
#  [6.37]
#  [6.47]]

# %%
print(y_test)
# Out:
# [4.1  3.49 2.08 2.33 1.94 1.48 1.86 3.09 4.21 2.87 3.65 4.   2.89 2.6
#  2.99 3.25 1.86 3.67 2.37 3.42 2.48 3.65 2.6  2.83 4.08 2.56 3.58 3.81
#  4.09 2.01 3.63 2.92 3.51 1.94 2.21 3.34 3.34 3.23 2.01 2.61]

# %%
plt.scatter(dataset['cgpa'],dataset['package'], color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('CGPA vs PACKAGE')
# Out:
# Text(0.5, 1.0, 'CGPA vs PACKAGE')

# %%
plt.scatter(X_train,y_train, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('CGPA vs PACKAGE')
# Out:
# Text(0.5, 1.0, 'CGPA vs PACKAGE')

# %%
plt.scatter(X_test,y_test, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('CGPA vs PACKAGE')
# Out:
# Text(0.5, 1.0, 'CGPA vs PACKAGE')

# %%
m = regressor.coef_
print(m)
# Out:
# [0.55795197]

# %%
b = regressor.intercept_
print(b)
# Out:
# -0.8961119222429144

# %%
# y = mx+b
m * 8.58 + b
# Out:
# array([3.89111601])

# %%
m * 9.5 + b
# Out:
# array([4.40443183])

# %%
m * 100 + b
# Out:
# array([54.89908542])

# %%
m * 7.15 + b
# Out:
# array([3.09324469])
